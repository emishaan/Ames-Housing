# %%
import numpy as np
import pandas as pd

# %%
housing = pd.read_csv('./train.csv')
housing.head()
# Out:
#          PID  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  528120170          20       RL         77.0    10872   Pave   NaN      IR1
# 1  535179060          20       RL         80.0    11900   Pave   NaN      IR1
# 2  528138030          60       RL         85.0    11924   Pave   NaN      IR1
# 3  526355170          20       RL         95.0    13651   Pave   NaN      IR1
# 4  909452050          80       RL          NaN    13607   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN        Shed    1500
#
# ...

# %%
housing.shape
# Out:
# (2051, 81)

# %%
pd.options.display.max_columns = 99

# %%
housing.head()
# Out:
#          PID  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  528120170          20       RL         77.0    10872   Pave   NaN      IR1
# 1  535179060          20       RL         80.0    11900   Pave   NaN      IR1
# 2  528138030          60       RL         85.0    11924   Pave   NaN      IR1
# 3  526355170          20       RL         95.0    13651   Pave   NaN      IR1
# 4  909452050          80       RL          NaN    13607   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      NridgHt       Norm
# 3         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 4         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
housing.isnull().sum().sort_values(ascending=False)
# Out:
# PoolQC           2042
# MiscFeature      1976
# Alley            1918
# Fence            1666
# FireplaceQu      1001
# LotFrontage       346
# GarageCond        119
# GarageFinish      119
# GarageYrBlt       119
# GarageQual        119
# GarageType        117
# BsmtExposure       60
# BsmtFinType2       60
# BsmtCond           59
# BsmtQual           59
# BsmtFinType1       59
# MasVnrType         19
# MasVnrArea         19
# BsmtHalfBath        2
# BsmtFullBath        2
# GarageCars          1
# GarageArea          1
# TotalBsmtSF         1
# BsmtUnfSF           1
# BsmtFinSF2          1
# BsmtFinSF1          1
# Electrical          1
# Exterior2nd         0
# Exterior1st         0
# RoofMatl            0
#                  ...
# ExterQual           0
# HeatingQC           0
# Foundation          0
# Heating             0
# SaleType            0
# YrSold              0
# MoSold              0
# MiscVal             0
# PoolArea            0
# ScreenPorch         0
# ...

# %%
dummies = pd.get_dummies(housing, drop_first=True)

# %%
dummies.shape
# Out:
# (2051, 252)
